# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('ProuniRelatorioDadosAbertos2020.csv', sep=';', encoding='latin-1')

# print(df.head())
# print(df.columns)

# tipoBolsas = df['TIPO_BOLSA'].value_counts()
# print(tipoBolsas)

# campus = df['CAMPUS'].value_counts()
# print(campus)

# curso = df['NOME_CURSO_BOLSA'].value_counts()
# print(curso)


tipoBolsas.plot(kind='bar')
plt.xlabel('TIPO_BOLSAS')
plt.title('Tipos de Bolsas')
plt.show()
